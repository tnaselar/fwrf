# %%
import numpy as np
import lasagne
import matplotlib.pyplot as plt
from fwrf.models import *
from fwrf.utils import make_rf_table
from scipy.stats.stats import pearsonr
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)

# %%
# %matplotlib inline

# %% [markdown]
# ### Set up a fwrf with white noise training/val data

# %%
Ttrn,Tval,D,V,nmaps = 2040,301,17,4,8
deg_per_stim = 20
sf = 10

##feature maps
trn_feature_map_dict = {}
for ii in range(1,nmaps+1):
    input_name = 'fmap_%0.2d' % (ii)
    trn_feature_map_dict[input_name] = np.random.random((Ttrn,D,sf*ii,sf*ii)).astype('float32')

val_feature_map_dict = {}
for ii in range(1,nmaps+1):
    input_name = 'fmap_%0.2d' % (ii)
    val_feature_map_dict[input_name] = np.random.random((Tval,D,sf*ii,sf*ii)).astype('float32')

test_feature_map_dict = {}
for ii in range(1,nmaps+1):
    input_name = 'fmap_%0.2d' % (ii)
    test_feature_map_dict[input_name] = np.random.random((Tval,D,sf*ii,sf*ii)).astype('float32')
    

##true rfs
bound = int((deg_per_stim-3)/2.)
true_rfs = {k:np.random.randint(-bound,high=bound, size=V).astype('float32') for k in ['x0','y0']}
true_rfs['sig'] = np.random.randint(1,high=bound,size=V).astype('float32')

##random rfs
rand_rfs = {k:np.random.randint(-bound,high=bound, size=V).astype('float32') for k in ['x0','y0']}
rand_rfs['sig'] = np.random.randint(1,high=bound,size=V).astype('float32')


##true feature weights
true_NU = np.random.random((D*nmaps,V)).astype('float32')

#random feature weights
rand_NU = np.random.random((D*nmaps,V)).astype('float32')

##fwrf model
true_model = fwrf(val_feature_map_dict,deg_per_stim,V,rf_init=true_rfs, NU=true_NU)
true_model.normalize(lambda: (yield trn_feature_map_dict))

##true outputs, trn/val
trn_voxel_activity = true_model.predict(trn_feature_map_dict).astype('float32')
val_voxel_activity = true_model.predict(val_feature_map_dict).astype('float32')
test_voxel_activity = true_model.predict(test_feature_map_dict).astype('float32')

##data generator: note these are functions that *return* generators, so we can reboot the generator whenever.
trn_batch_size = Ttrn
val_batch_size = Tval
trn_data_gen = lambda: (({k:v[ii:ii+trn_batch_size,:,:,:] for k,v in trn_feature_map_dict.iteritems()}, trn_voxel_activity[ii:ii+trn_batch_size,:]) for ii in range(0,Ttrn,trn_batch_size))
val_data_gen = lambda: (({k:v[ii:ii+val_batch_size,:,:,:] for k,v in val_feature_map_dict.iteritems()}, val_voxel_activity[ii:ii+val_batch_size,:]) for ii in range(0,Tval,val_batch_size))       

##rf grid for coarse training
deg_per_radius = (1,deg_per_stim,12)
spacing = 2
rf_grid_df = make_rf_table(deg_per_stim,deg_per_radius,spacing,pix_per_stim = None)
G = rf_grid_df.shape[0]
rf_grid = {}
rf_grid['x0'] = rf_grid_df.x_deg.values.astype('float32')
rf_grid['y0'] = rf_grid_df.y_deg.values.astype('float32')
rf_grid['sig'] = rf_grid_df.deg_per_radius.values.astype('float32')
print G
# Out:
# 1200

# %%
val_data_gen().next()[0]['fmap_01'].shape
# Out:
# (301, 17, 10, 10)

# %% [markdown]
# ### Coarse vs. fine training (deterministic gradient descent)

# %% [markdown]
# ####  coarse only

# %%
coarse_model = fwrf(val_feature_map_dict,deg_per_stim,V,rf_init=rand_rfs, NU=rand_NU)
# coarse_model.normalize(lambda: (yield trn_feature_map_dict))
_=coarse_model.train_me(trn_data_gen, val_data_gen,
                        coarse=True,
                        rf_grid=rf_grid,
                        learning_rate=10e-6,
                        epochs=1,
                        num_iters = 100,
                        check_every=1,
                        print_stuff=True,
                        check_dims=False,
                        normalize=True,
                        consolidate=False)
# Out:
# will solve for: [feature_weights]
# will update wrt: [feature_weights]
# compiling...
# =======epoch: 0
# ====iter: 0
# number of improved models: 4366
# trn error: 501985600.000000
# ====iter: 1
# number of improved models: 4292
# trn error: 489303264.000000
# ====iter: 2
# number of improved models: 4205
# trn error: 477736896.000000
# ====iter: 3
# number of improved models: 4129
# trn error: 467185600.000000
# ====iter: 4
# number of improved models: 4065
# trn error: 457556032.000000
# ====iter: 5
# number of improved models: 3986
# trn error: 448763552.000000
# ====iter: 6
# number of improved models: 3932
# trn error: 440732160.000000
# ====iter: 7
# number of improved models: 3877
# trn error: 433392448.000000
# ====iter: 8
# number of improved models: 3825
# trn error: 426681728.000000
# ====iter: 9
# number of improved models: 3768
# trn error: 420543488.000000
# ====iter: 10
# number of improved models: 3715
# trn error: 414926336.000000
# ====iter: 11
# number of improved models: 3658
# trn error: 409783776.000000
# ====iter: 12
# number of improved models: 3599
# trn error: 405073536.000000
# ====iter: 13
# number of improved models: 3548
# trn error: 400757600.000000
# ====iter: 14
# number of improved models: 3494
# trn error: 396800640.000000
# ====iter: 15
# number of improved models: 3412
# trn error: 393171808.000000
# ====iter: 16
# number of improved models: 3332
# trn error: 389842048.000000
# ====iter: 17
# number of improved models: 3256
# trn error: 386785248.000000
# ====iter: 18
# number of improved models: 3160
# trn error: 383978176.000000
# ====iter: 19
# number of improved models: 3065
# trn error: 381398976.000000
# ====iter: 20
# number of improved models: 2962
# trn error: 379028288.000000
# ====iter: 21
# number of improved models: 2867
# trn error: 376848384.000000
# ====iter: 22
# number of improved models: 2768
# trn error: 374842752.000000
# ====iter: 23
# number of improved models: 2679
# trn error: 372996896.000000
# ====iter: 24
# number of improved models: 2602
# trn error: 371297408.000000
# ====iter: 25
# number of improved models: 2533
# trn error: 369731840.000000
# ====iter: 26
# number of improved models: 2471
# trn error: 368289120.000000
# ====iter: 27
# number of improved models: 2410
# trn error: 366958912.000000
# ====iter: 28
# number of improved models: 2357
# trn error: 365732096.000000
# ====iter: 29
# number of improved models: 2306
# trn error: 364600192.000000
# ====iter: 30
# number of improved models: 2260
# trn error: 363555488.000000
# ====iter: 31
# number of improved models: 2212
# trn error: 362590560.000000
# ====iter: 32
# number of improved models: 2165
# trn error: 361699136.000000
# ====iter: 33
# number of improved models: 2129
# trn error: 360875424.000000
# ====iter: 34
# number of improved models: 2088
# trn error: 360113856.000000
# ====iter: 35
# number of improved models: 2046
# trn error: 359409408.000000
# ====iter: 36
# number of improved models: 2016
# trn error: 358757696.000000
# ====iter: 37
# number of improved models: 1984
# trn error: 358154336.000000
# ====iter: 38
# number of improved models: 1957
# trn error: 357595712.000000
# ====iter: 39
# number of improved models: 1934
# trn error: 357078368.000000
# ====iter: 40
# number of improved models: 1911
# trn error: 356598848.000000
# ====iter: 41
# number of improved models: 1881
# trn error: 356154304.000000
# ====iter: 42
# number of improved models: 1852
# trn error: 355742336.000000
# ====iter: 43
# number of improved models: 1825
# trn error: 355359936.000000
# ====iter: 44
# number of improved models: 1791
# trn error: 355005248.000000
# ====iter: 45
# number of improved models: 1766
# trn error: 354675904.000000
# ====iter: 46
# number of improved models: 1743
# trn error: 354370112.000000
# ====iter: 47
# number of improved models: 1724
# trn error: 354085952.000000
# ====iter: 48
# number of improved models: 1698
# trn error: 353822080.000000
# ====iter: 49
# number of improved models: 1671
# trn error: 353576672.000000
# ====iter: 50
# number of improved models: 1636
# trn error: 353348704.000000
# ====iter: 51
# number of improved models: 1607
# trn error: 353136416.000000
# ====iter: 52
# number of improved models: 1581
# trn error: 352939072.000000
# ====iter: 53
# number of improved models: 1557
# trn error: 352755360.000000
# ====iter: 54
# number of improved models: 1529
# trn error: 352584320.000000
# ====iter: 55
# number of improved models: 1505
# trn error: 352425152.000000
# ====iter: 56
# number of improved models: 1470
# trn error: 352276800.000000
# ====iter: 57
# number of improved models: 1429
# trn error: 352138624.000000
# ====iter: 58
# number of improved models: 1396
# trn error: 352009728.000000
# ====iter: 59
# number of improved models: 1359
# trn error: 351889600.000000
# ====iter: 60
# number of improved models: 1316
# trn error: 351777664.000000
# ====iter: 61
# number of improved models: 1275
# trn error: 351673120.000000
# ====iter: 62
# number of improved models: 1234
# trn error: 351575616.000000
# ====iter: 63
# number of improved models: 1192
# trn error: 351484608.000000
# ====iter: 64
# number of improved models: 1134
# trn error: 351399808.000000
# ====iter: 65
# number of improved models: 1086
# trn error: 351320448.000000
# ====iter: 66
# number of improved models: 1025
# trn error: 351246368.000000
# ====iter: 67
# number of improved models: 980
# trn error: 351177216.000000
# ====iter: 68
# number of improved models: 919
# trn error: 351112576.000000
# ====iter: 69
# number of improved models: 857
# trn error: 351052096.000000
# ====iter: 70
# number of improved models: 790
# trn error: 350995616.000000
# ====iter: 71
# number of improved models: 719
# trn error: 350942912.000000
# ====iter: 72
# number of improved models: 656
# trn error: 350893536.000000
# ====iter: 73
# number of improved models: 594
# trn error: 350847296.000000
# ====iter: 74
# number of improved models: 535
# trn error: 350804160.000000
# ====iter: 75
# number of improved models: 465
# trn error: 350763648.000000
# ====iter: 76
# number of improved models: 364
# trn error: 350725760.000000
# ====iter: 77
# number of improved models: 309
# trn error: 350690368.000000
# ====iter: 78
# number of improved models: 282
# trn error: 350657120.000000
# ====iter: 79
# number of improved models: 263
# trn error: 350625984.000000
# ====iter: 80
# number of improved models: 247
# trn error: 350596800.000000
# ====iter: 81
# number of improved models: 234
# trn error: 350569472.000000
# ====iter: 82
# number of improved models: 217
# trn error: 350543872.000000
# ====iter: 83
# number of improved models: 205
# trn error: 350520032.000000
# ====iter: 84
# number of improved models: 199
# trn error: 350497472.000000
# ====iter: 85
# number of improved models: 192
# trn error: 350476384.000000
# ====iter: 86
# number of improved models: 187
# trn error: 350456576.000000
# ====iter: 87
# number of improved models: 180
# trn error: 350438144.000000
# ====iter: 88
# number of improved models: 176
# trn error: 350420640.000000
# ====iter: 89
# number of improved models: 172
# trn error: 350404288.000000
# ====iter: 90
# number of improved models: 168
# trn error: 350388992.000000
# ====iter: 91
# number of improved models: 166
# trn error: 350374752.000000
# ====iter: 92
# number of improved models: 160
# trn error: 350361184.000000
# ====iter: 93
# number of improved models: 154
# trn error: 350348544.000000
# ====iter: 94
# number of improved models: 150
# trn error: 350336576.000000
# ====iter: 95
# number of improved models: 146
# trn error: 350325504.000000
# ====iter: 96
# number of improved models: 140
# trn error: 350315008.000000
# ====iter: 97
# number of improved models: 139
# trn error: 350305280.000000
# ====iter: 98
# number of improved models: 137
# trn error: 350295904.000000
# ====iter: 99
# number of improved models: 135
# trn error: 350287168.000000

# %%
test_pred_activity = coarse_model.predict(test_feature_map_dict)

# %%
plt.plot(test_pred_activity, test_voxel_activity,'.')
plt.axis('equal')
# Out:
# (-30.0, 30.0, -30.0, 30.0)

# %% [markdown]
# #### fine only

# %%
fine_model = fwrf(val_feature_map_dict,deg_per_stim,V,rf_init=rand_rfs, NU=rand_NU)
fine_model.normalize(lambda: (yield trn_feature_map_dict))
_=fine_model.train_me(trn_data_gen, val_data_gen,
                      fine=True,
                      learning_rate=10e-11,
                      epochs=1,
                      num_iters = 100,
                      check_every=1,
                      print_stuff=True,
                      check_dims=False)
# Out:
# will solve for: [rf_fmap_08.x0, rf_fmap_08.y0, rf_fmap_08.sig, feature_weights]
# will update wrt: [rf_fmap_08.x0, rf_fmap_08.y0, rf_fmap_08.sig, feature_weights]
# compiling...
# =======epoch: 0
# ====iter: 0
# number of improved models: 2
# trn error: 511169.562500
# ====iter: 1
# number of improved models: 1
# trn error: 511170.062500
# ====iter: 2
# number of improved models: 0
# trn error: 511180.062500
# ====iter: 3
# number of improved models: 0
# trn error: 511278.875000
# ====iter: 4
# number of improved models: 0
# trn error: 512252.906250
# ====iter: 5
# number of improved models: 0
# trn error: 521787.781250
# ====iter: 6
# number of improved models: 0
# trn error: 615068.375000
# ====iter: 7
# number of improved models: 0
# trn error: 1527423.000000
# ====iter: 8
# number of improved models: 0
# trn error: 10459391.000000
# ====iter: 9
# number of improved models: 0
# trn error: 97444968.000000
# ====iter: 10
# number of improved models: 0
# trn error: 938656128.000000
# ====iter: 11
# number of improved models: 0
# trn error: 7620366848.000000
# ====iter: 12
# number of improved models: 0
# trn error: 10257738752.000000
# ====iter: 13
# number of improved models: 0
# trn error: 18280105984.000000
# ====iter: 14
# number of improved models: 0
# trn error: 12468193280.000000
# ====iter: 15
# number of improved models: 0
# trn error: 8506725888.000000
# ====iter: 16
# number of improved models: 0
# trn error: 5805570560.000000
# ====iter: 17
# number of improved models: 0
# trn error: 3963086848.000000
# ====iter: 18
# number of improved models: 0
# trn error: 2705888000.000000
# ====iter: 19
# number of improved models: 0
# trn error: 1847811584.000000
# ====iter: 20
# number of improved models: 0
# trn error: 1262019584.000000
# ====iter: 21
# number of improved models: 0
# trn error: 862044736.000000
# ====iter: 22
# number of improved models: 0
# trn error: 588911488.000000
# ====iter: 23
# number of improved models: 0
# trn error: 402379360.000000
# ====iter: 24
# number of improved models: 0
# trn error: 274982304.000000
# ====iter: 25
# number of improved models: 0
# trn error: 187969456.000000
# ====iter: 26
# number of improved models: 1
# trn error: 128537488.000000
# ====iter: 27
# number of improved models: 0
# trn error: 87943112.000000
# ====iter: 28
# number of improved models: 0
# trn error: 60215168.000000
# ====iter: 29
# number of improved models: 0
# trn error: 41275460.000000
# ====iter: 30
# number of improved models: 0
# trn error: 28338522.000000
# ====iter: 31
# number of improved models: 0
# trn error: 19501778.000000
# ====iter: 32
# number of improved models: 0
# trn error: 13465714.000000
# ====iter: 33
# number of improved models: 0
# trn error: 9342678.000000
# ====iter: 34
# number of improved models: 0
# trn error: 6526367.000000
# ====iter: 35
# number of improved models: 0
# trn error: 4602638.000000
# ====iter: 36
# number of improved models: 1
# trn error: 3288598.250000
# ====iter: 37
# number of improved models: 0
# trn error: 2391020.750000
# ====iter: 38
# number of improved models: 1
# trn error: 1777913.750000
# ====iter: 39
# number of improved models: 1
# trn error: 1359117.750000
# ====iter: 40
# number of improved models: 1
# trn error: 1073052.125000
# ====iter: 41
# number of improved models: 0
# trn error: 877649.500000
# ====iter: 42
# number of improved models: 0
# trn error: 744175.687500
# ====iter: 43
# number of improved models: 1
# trn error: 653004.000000
# ====iter: 44
# number of improved models: 1
# trn error: 590727.125000
# ====iter: 45
# number of improved models: 1
# trn error: 548188.000000
# ====iter: 46
# number of improved models: 2
# trn error: 519130.781250
# ====iter: 47
# number of improved models: 2
# trn error: 499282.375000
# ====iter: 48
# number of improved models: 1
# trn error: 485724.656250
# ====iter: 49
# number of improved models: 2
# trn error: 476463.843750
# ====iter: 50
# number of improved models: 1
# trn error: 470137.656250
# ====iter: 51
# number of improved models: 2
# trn error: 465816.812500
# ====iter: 52
# number of improved models: 1
# trn error: 462864.937500
# ====iter: 53
# number of improved models: 2
# trn error: 460848.625000
# ====iter: 54
# number of improved models: 1
# trn error: 459471.531250
# ====iter: 55
# number of improved models: 2
# trn error: 458530.687500
# ====iter: 56
# number of improved models: 1
# trn error: 457887.937500
# ====iter: 57
# number of improved models: 2
# trn error: 457448.937500
# ====iter: 58
# number of improved models: 1
# trn error: 457148.906250
# ====iter: 59
# number of improved models: 2
# trn error: 456944.062500
# ====iter: 60
# number of improved models: 1
# trn error: 456803.937500
# ====iter: 61
# number of improved models: 2
# trn error: 456708.250000
# ====iter: 62
# number of improved models: 1
# trn error: 456643.000000
# ====iter: 63
# number of improved models: 2
# trn error: 456598.031250
# ====iter: 64
# number of improved models: 1
# trn error: 456567.468750
# ====iter: 65
# number of improved models: 2
# trn error: 456546.531250
# ====iter: 66
# number of improved models: 1
# trn error: 456532.187500
# ====iter: 67
# number of improved models: 2
# trn error: 456522.281250
# ====iter: 68
# number of improved models: 1
# trn error: 456515.437500
# ====iter: 69
# number of improved models: 2
# trn error: 456510.937500
# ====iter: 70
# number of improved models: 1
# trn error: 456507.656250
# ====iter: 71
# number of improved models: 1
# trn error: 456505.281250
# ====iter: 72
# number of improved models: 1
# trn error: 456503.750000
# ====iter: 73
# number of improved models: 1
# trn error: 456502.656250
# ====iter: 74
# number of improved models: 1
# trn error: 456501.812500
# ====iter: 75
# number of improved models: 1
# trn error: 456501.250000
# ====iter: 76
# number of improved models: 1
# trn error: 456500.750000
# ====iter: 77
# number of improved models: 1
# trn error: 456500.500000
# ====iter: 78
# number of improved models: 1
# trn error: 456500.125000
# ====iter: 79
# number of improved models: 1
# trn error: 456499.937500
# ====iter: 80
# number of improved models: 1
# trn error: 456499.656250
# ====iter: 81
# number of improved models: 1
# trn error: 456499.468750
# ====iter: 82
# number of improved models: 2
# trn error: 456499.281250
# ====iter: 83
# number of improved models: 2
# trn error: 456499.000000
# ====iter: 84
# number of improved models: 1
# trn error: 456498.968750
# ====iter: 85
# number of improved models: 2
# trn error: 456498.781250
# ====iter: 86
# number of improved models: 1
# trn error: 456498.625000
# ====iter: 87
# number of improved models: 2
# trn error: 456498.531250
# ====iter: 88
# number of improved models: 1
# trn error: 456498.312500
# ====iter: 89
# number of improved models: 2
# trn error: 456498.312500
# ====iter: 90
# number of improved models: 2
# trn error: 456498.031250
# ====iter: 91
# number of improved models: 2
# trn error: 456497.937500
# ====iter: 92
# number of improved models: 1
# trn error: 456497.750000
# ====iter: 93
# number of improved models: 2
# trn error: 456497.687500
# ====iter: 94
# number of improved models: 1
# trn error: 456497.562500
# ====iter: 95
# number of improved models: 2
# trn error: 456497.281250
# ====iter: 96
# number of improved models: 1
# trn error: 456497.187500
# ====iter: 97
# number of improved models: 2
# trn error: 456497.062500
# ====iter: 98
# number of improved models: 1
# trn error: 456496.937500
# ====iter: 99
# number of improved models: 2
# trn error: 456496.812500

# %%
test_pred_activity = fine_model.predict(test_feature_map_dict)

# %%
plt.plot(test_pred_activity, test_voxel_activity,'.')
plt.axis('equal')
# Out:
# (-20.0, 20.0, -30.0, 30.0)

# %% [markdown]
# #### now try fine-tuning the coarse model

# %%
##renormalize

# %%
_=coarse_model.train_me(trn_data_gen, val_data_gen,
                      fine=True,
                      learning_rate=10e-11,
                      epochs=1,
                      num_iters = 100,
                      check_every=1,
                      print_stuff=True,
                      check_dims=False)

# %%
test_pred_activity = coarse_model.predict(test_feature_map_dict)

# %%
plt.plot(test_pred_activity, test_voxel_activity,'.')
plt.axis('equal')
